# %% [markdown]
# ### Sivarajan - 2021FC04989 - CompExam notebook

# %%
## import the libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
exam = pd.read_csv("makeup_exam.csv")
sns.catplot(kind="box",data=exam.head(100))
plt.xlabel("Position")
plt.ylabel("Thickness")
# Out:
# Text(-9.075000000000003, 0.5, 'Thickness')
